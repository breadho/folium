# %% [markdown]
# ## Physics Toolbox Suite 데이터 수집

# %% [markdown]
# - 수집일: 2023-09-28, 2023-09-29
# - 수집구간
#     * (1구간) 고성 문암리 -> 원통 우체국
#     * (2구간) 원통 우체국 -> 양구 성곡재 인근
#     * (3구간) 양구 성곡재 인근 -> 화천터미널
#     * (4구간) 화천터미널 -> 47번 국도 합류점
#     * (5구간) 47번 국도 합류점 -> 의정부
#     * (6구간) 의정부 -> 춘천 위도 인근
#     * (7구간) 춘천 or 가평 인근 -> 의정부

# %% [markdown]
# - 수집결과 확인

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
import os
os.listdir('./data')
# Out:
# ['2023-09-2807.21.27.csv',
#  '2023-09-2808.37.36.csv',
#  '2023-09-2809.43.39.csv',
#  '2023-09-2810.47.01.csv',
#  '2023-09-2811.48.46.csv',
#  '2023-09-2907.36.24.csv',
#  '2023-09-2911.38.17.csv',
#  '2023-09-2912.38.09.csv',
#  's7FE']

# %%
df1 = pd.read_csv('2023-09-2807.21.27.csv')

# %%
df.head(20)
# Out:
#             time     gFx     gFy     gFz   ax   ay   az      wx      wy  \
# 0   07:21:27:939  1.0041 -0.0458  0.0225  0.0  0.0  0.0  0.0000  0.0000
# 1   07:21:27:975  1.0041 -0.0458  0.0225  0.0  0.0  0.0  0.0443 -0.0096
# 2   07:21:27:985  1.0041 -0.0458  0.0225  0.0  0.0  0.0  0.0443 -0.0096
# 3   07:21:28:003  0.9924 -0.0002 -0.0425  0.0  0.0  0.0  0.0443 -0.0096
# 4   07:21:28:005  0.9995  0.0190 -0.0742  0.0  0.0  0.0  0.0443 -0.0096
# 5   07:21:28:006  0.9898 -0.0038 -0.0446  0.0  0.0  0.0  0.0443 -0.0096
# 6   07:21:28:007  1.0102 -0.0380  0.0233  0.0  0.0  0.0  0.0443 -0.0096
# 7   07:21:28:041  1.0102 -0.0380  0.0233  0.0  0.0  0.0 -0.0151 -0.0050
# 8   07:21:28:045  1.0102 -0.0380  0.0233  0.0  0.0  0.0 -0.0151 -0.0050
# 9   07:21:28:047  1.0102 -0.0380  0.0233  0.0  0.0  0.0 -0.0151 -0.0050
# 10  07:21:28:050  1.0102 -0.0380  0.0233  0.0  0.0  0.0 -0.0151 -0.0050
# 11  07:21:28:070  1.0349 -0.0682  0.0228  0.0  0.0  0.0 -0.0151 -0.0050
# ...

# %%
df.tail(20)
# Out:
#                 time     gFx     gFy     gFz      ax      ay      az      wx  \
# 555648  08:25:22:367  1.0135 -0.0504  0.0258 -0.0179  0.1191 -0.1391 -0.0177
# 555649  08:25:22:369  0.9752 -0.0153 -0.0129 -0.0179  0.1191 -0.1391 -0.0177
# 555650  08:25:22:371  0.9861  0.0065 -0.0262 -0.0179  0.1191 -0.1391 -0.0177
# 555651  08:25:22:372  0.9861  0.0065 -0.0262 -0.0179  0.1191 -0.1391 -0.0177
# 555652  08:25:22:383  0.9861  0.0065 -0.0262 -0.0179  0.1191 -0.1391  0.0078
# 555653  08:25:22:391  1.0050 -0.0200 -0.0109 -0.0179  0.1191 -0.1391  0.0078
# 555654  08:25:22:393  1.0050 -0.0200 -0.0109 -0.0179  0.1191 -0.1391  0.0078
# 555655  08:25:22:394  1.0299 -0.0544  0.0276 -0.0179  0.1191 -0.1391  0.0078
# 555656  08:25:22:395  1.0299 -0.0544  0.0276  0.1407 -0.1813  0.1722  0.0078
# 555657  08:25:22:405  1.0299 -0.0544  0.0276  0.1407 -0.1813  0.1722  0.0078
# 555658  08:25:22:407  1.0299 -0.0544  0.0276  0.1407 -0.1813  0.1722  0.0078
# ...

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.gFx.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.gFy.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Out:
# <Axes: ylabel='Frequency'>

# %%
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numba\core\decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\visions\backends\shared\nan_handling.py:51: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def hasna(x: np.ndarray) -> bool:

# %%
profile = ProfileReport(df, title="ydata_profiling Report2", minimal = True)

# %%
profile.to_file("ydata_report_2.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555668 entries, 0 to 555667
# Data columns (total 22 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   time         555668 non-null  object
#  1   gFx          555668 non-null  float64
#  2   gFy          555668 non-null  float64
#  3   gFz          555668 non-null  float64
#  4   ax           555668 non-null  float64
#  5   ay           555668 non-null  float64
#  6   az           555668 non-null  float64
#  7   wx           555668 non-null  float64
#  8   wy           555668 non-null  float64
#  9   wz           555668 non-null  float64
#  10  p            555668 non-null  float64
#  11  Bx           555668 non-null  float64
#  12  By           555668 non-null  float64
#  13  Bz           555668 non-null  float64
#  14  I            555668 non-null  float64
#  15  Azimuth      555668 non-null  float64
#  16  Pitch        555668 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['time', 'gFx', 'gFy', 'gFz', 'ax', 'ay', 'az', 'wx', 'wy', 'wz', 'p',
#        'Bx', 'By', 'Bz', 'I', 'Azimuth', 'Pitch', 'Roll', 'Latitude',
#        'Longitude', 'Speed (m/s)', 'Unnamed: 21'],
#       dtype='object')

# %%
df.loc[200000:250000, 'Speed (m/s)'].plot.line()
# Out:
# <Axes: >
